# %%
#weather2020 data exploration
#library import
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
weather = pd.read_csv("C:/Users/SRTINNI/Desktop/TPW/flevy.com-coronavirus-bangladesh.csv")

# %%
weather.head()
# Out:
#          Date  Total Cases  New Cases  New Cases 7-Day Moving Average  \
# 0  2021-03-06       549724        540                             556
# 1  2021-03-05       549184        635                             537
# 2  2021-03-04       548549        619                             514
# 3  2021-03-03       547930        614                             484
# 4  2021-03-02       547316        515                             457
#
#   Case Growth Cases Growth 7DMA  Total Deaths  New Deaths  New Deaths 7DMA  \
# 0        0.1%              0.1%          8451          10                7
# 1       0.12%              0.1%          8441           6                7
# 2       0.11%             0.09%          8435           7                7
# 3       0.11%             0.09%          8428           5                7
# 4       0.09%             0.08%          8423           7                7
#
#   Death Growth Death Growth 7DMA  Total Recoveries  New Recoveries  \
# 0        0.12%             0.09%            501966             822
# 1        0.07%             0.08%            501144             676
# 2        0.08%             0.09%            500468             841
# 3        0.06%             0.08%            499627            1236
# 4        0.08%             0.08%            498391             594
#
#   Recovery Rate  Active Cases Case Fatality Rate (CFR) Adjusted CFR  \
# 0        91.31%         39307                    1.54%        1.66%
# 1        91.25%         39599                    1.54%        1.66%
# 2        91.23%         39646                    1.54%        1.66%
# 3        91.18%         39875                    1.54%        1.66%
# 4        91.06%         40502                    1.54%        1.66%
#
#    Total Deaths per MM Population  Total Cases per MM Population  \
# 0                           51.31                        3337.95
# 1                           51.25                        3334.67
# 2                           51.22                        3330.82
# 3                           51.18                        3327.06
# 4                           51.14                        3323.33
#
#    Active Cases per ICU Bed
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
weather.tail()
# Out:
#            Date  Total Cases  New Cases  New Cases 7-Day Moving Average  \
# 359  2020-03-12            3          0                               1
# 360  2020-03-11            3          0                               1
# 361  2020-03-10            3          0                               1
# 362  2020-03-09            3          0                               2
# 363  2020-03-08            3          3                               3
#
#     Case Growth Cases Growth 7DMA  Total Deaths  New Deaths  New Deaths 7DMA  \
# 359           0                 0             0           0                0
# 360           0                 0             0           0                0
# 361           0                 0             0           0                0
# 362           0                 0             0           0                0
# 363           0                 0             0           0                0
#
#     Death Growth Death Growth 7DMA  Total Recoveries  New Recoveries  \
# 359            0                 0                 0               0
# 360            0                 0                 0               0
# 361            0                 0                 0               0
# 362            0                 0                 0               0
# 363            0                 0                 0               0
#
#     Recovery Rate  Active Cases Case Fatality Rate (CFR) Adjusted CFR  \
# 359            0%             3                       0%            0
# 360            0%             3                       0%            0
# 361            0%             3                       0%            0
# 362            0%             3                       0%            0
# 363            0%             3                       0%            0
#
#      Total Deaths per MM Population  Total Cases per MM Population  \
# 359                             0.0                           0.02
# 360                             0.0                           0.02
# 361                             0.0                           0.02
# 362                             0.0                           0.02
# 363                             0.0                           0.02
#
#      Active Cases per ICU Bed
# 359                       NaN
# 360                       NaN
# 361                       NaN
# 362                       NaN
# 363                       NaN

# %%
weather.columns
# Out:
# Index(['Date', 'Total Cases', 'New Cases', 'New Cases 7-Day Moving Average',
#        'Case Growth', 'Cases Growth 7DMA', 'Total Deaths', 'New Deaths',
#        'New Deaths 7DMA', 'Death Growth', 'Death Growth 7DMA',
#        'Total Recoveries', 'New Recoveries', 'Recovery Rate', 'Active Cases',
#        'Case Fatality Rate (CFR)', 'Adjusted CFR',
#        'Total Deaths per MM Population', 'Total Cases per MM Population',
#        'Active Cases per ICU Bed'],
#       dtype='object')

# %%
weather.shape
# Out:
# (364, 20)

# %%
weather.describe()
# Out:
#          Total Cases    New Cases  New Cases 7-Day Moving Average  \
# count     364.000000   364.000000                      364.000000
# mean   284494.640110  1510.230769                     1505.392857
# std    199084.594824  1049.185081                     1031.918696
# min         3.000000     0.000000                        0.000000
# 25%     65083.250000   561.000000                      534.250000
# 50%    324361.000000  1473.000000                     1462.500000
# 75%    476228.000000  2273.500000                     2186.250000
# max    549724.000000  4019.000000                     3810.000000
#
#        Total Deaths  New Deaths  New Deaths 7DMA  Total Recoveries  \
# count    364.000000  364.000000       364.000000        364.000000
# mean    4108.074176   23.217033        23.192308     222493.703297
# std     2983.379865   14.239766        13.449891     183324.776781
# min        0.000000    0.000000         0.000000          0.000000
# 25%      877.500000   13.000000        11.000000      13758.500000
# 50%     4463.000000   22.000000        23.500000     219563.500000
# 75%     6814.750000   35.000000        34.000000     394046.000000
# max     8451.000000   64.000000        45.000000     501966.000000
#
#        New Recoveries   Active Cases  Total Deaths per MM Population  \
# count      364.000000     364.000000                      364.000000
# mean      1379.027473   57892.862637                       24.944176
# std       1367.809858   33867.359741                       18.115181
# min          0.000000       3.000000                        0.000000
# 25%        471.500000   40566.500000                        5.327500
# 50%       1415.500000   61300.000000                       27.100000
# 75%       1956.500000   83166.750000                       41.377500
# max      17533.000000  115779.000000                       51.310000
#
#        Total Cases per MM Population  Active Cases per ICU Bed
# count                     364.000000                       0.0
# mean                     1727.465797                       NaN
# std                      1208.851567                       NaN
# min                         0.020000                       NaN
# 25%                       395.187500                       NaN
# 50%                      1969.535000                       NaN
# 75%                      2891.685000                       NaN
# max                      3337.950000                       NaN

# %%
weather.isnull().sum()
# Out:
# Date                                0
# Total Cases                         0
# New Cases                           0
# New Cases 7-Day Moving Average      0
# Case Growth                         0
# Cases Growth 7DMA                   0
# Total Deaths                        0
# New Deaths                          0
# New Deaths 7DMA                     0
# Death Growth                        0
# Death Growth 7DMA                   0
# Total Recoveries                    0
# New Recoveries                      0
# Recovery Rate                       0
# Active Cases                        0
# Case Fatality Rate (CFR)            0
# Adjusted CFR                        0
# Total Deaths per MM Population      0
# Total Cases per MM Population       0
# Active Cases per ICU Bed          364
# dtype: int64

# %%
correlation = weather.corr()

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(weather)
