# %%
#Covid march april data 2020 data exploration
#library import
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
case = pd.read_csv("C:/Users/SRTINNI/Desktop/TPW/Classification&Prediction/marchapril20.csv")

# %%
#understanding data using head,tail,shape ,describe etc
case.head()
# Out:
#          Date  Total Cases  New Cases  New Cases 7-Day Moving Average  \
# 0    08-04-20          218         54                              23
# 1    07-04-20          164         41                              16
# 2    06-04-20          123         35                              11
# 3    05-04-20           88         18                               6
# 4    04-04-20           70          9                               3
#
#   Case Growth Cases Growth 7DMA  Total Deaths  New Deaths  New Deaths 7DMA  \
# 0      32.93%            22.73%            20           3                2
# 1      33.33%            18.87%            17           5                2
# 2      39.77%            14.69%            12           3                1
# 3      25.71%             9.30%             9           1                1
# 4      14.75%             5.63%             8           2                0
#
#   Death Growth Death Growth 7DMA  Total Recoveries  New Recoveries  \
# ...

# %%
case.tail()
# Out:
#           Date  Total Cases  New Cases  New Cases 7-Day Moving Average  \
# 27    12-03-20            3          0                               1
# 28    11-03-20            3          0                               1
# 29    10-03-20            3          0                               1
# 30    09-03-20            3          0                               2
# 31    08-03-20            3          3                               3
#
#    Case Growth Cases Growth 7DMA  Total Deaths  New Deaths  New Deaths 7DMA  \
# 27           0                 0             0           0                0
# 28           0                 0             0           0                0
# 29           0                 0             0           0                0
# 30           0                 0             0           0                0
# 31           0                 0             0           0                0
#
#    Death Growth Death Growth 7DMA  Total Recoveries  New Recoveries  \
# ...

# %%
case.columns
# Out:
# Index(['       Date', 'Total Cases', 'New Cases',
#        'New Cases 7-Day Moving Average', 'Case Growth', 'Cases Growth 7DMA',
#        'Total Deaths', 'New Deaths', 'New Deaths 7DMA', 'Death Growth',
#        'Death Growth 7DMA', 'Total Recoveries', 'New Recoveries',
#        'Recovery Rate', 'Active Cases', 'Case Fatality Rate (CFR)',
#        'Adjusted CFR', 'Total Deaths per MM Population',
#        'Total Cases per MM Population', 'Active Cases per ICU Bed'],
#       dtype='object')

# %%
case.shape
# Out:
# (32, 20)

# %%
case.describe()
# Out:
#        Total Cases  New Cases  New Cases 7-Day Moving Average  Total Deaths  \
# count    32.000000  32.000000                       32.000000      32.00000
# mean     43.125000   6.812500                        3.687500       4.15625
# std      48.501912  12.683333                        4.693424       4.89970
# min       3.000000   0.000000                        0.000000       0.00000
# 25%       7.250000   0.000000                        1.750000       0.00000
# 50%      36.000000   3.000000                        2.000000       3.50000
# 75%      51.750000   5.000000                        4.000000       5.25000
# max     218.000000  54.000000                       23.000000      20.00000
#
#        New Deaths  New Deaths 7DMA  Total Recoveries  New Recoveries  \
# count   32.000000        32.000000         32.000000       32.000000
# mean     0.625000         0.312500         11.593750        1.031250
# std      1.157026         0.592289         12.333692        1.694096
# ...

# %%
case.nunique()
# Out:
#        Date                       32
# Total Cases                       23
# New Cases                         12
# New Cases 7-Day Moving Average     9
# Case Growth                       22
# Cases Growth 7DMA                 26
# Total Deaths                      12
# New Deaths                         5
# New Deaths 7DMA                    3
# Death Growth                       9
# Death Growth 7DMA                 14
# Total Recoveries                  12
# New Recoveries                     6
# Recovery Rate                     23
# Active Cases                      21
# Case Fatality Rate (CFR)          21
# Adjusted CFR                      17
# Total Deaths per MM Population     9
# Total Cases per MM Population     23
# Active Cases per ICU Bed           0
# dtype: int64

# %%
case['New Cases'].unique()
# Out:
# array([54, 41, 35, 18,  9,  5,  2,  3,  1,  0,  4,  6], dtype=int64)

# %%
case['New Deaths'].unique()
# Out:
# array([3, 5, 1, 2, 0], dtype=int64)

# %%
case['Active Cases'].unique()
# Out:
# array([165, 114,  78,  46,  32,  29,  25,  23,  21,  28,  27,  30,  22,
#         20,  16,  13,  10,   7,   6,   5,   3], dtype=int64)

# %%
# cleaning data, it says drop the unncesseary data,check whether therr is duplicacy,null value

case.isnull().sum()
# Out:
#        Date                        0
# Total Cases                        0
# New Cases                          0
# New Cases 7-Day Moving Average     0
# Case Growth                        0
# Cases Growth 7DMA                  0
# Total Deaths                       0
# New Deaths                         0
# New Deaths 7DMA                    0
# Death Growth                       0
# Death Growth 7DMA                  0
# Total Recoveries                   0
# New Recoveries                     0
# Recovery Rate                      0
# Active Cases                       0
# Case Fatality Rate (CFR)           0
# Adjusted CFR                       0
# Total Deaths per MM Population     0
# Total Cases per MM Population      0
# Active Cases per ICU Bed          32
# dtype: int64

# %%
case['Active Cases per ICU Bed'].unique()
# Out:
# array([nan])

# %%
cases = case.drop(['Active Cases per ICU Bed'],axis = 1)

# %%
cases.head()
# Out:
#          Date  Total Cases  New Cases  New Cases 7-Day Moving Average  \
# 0    08-04-20          218         54                              23
# 1    07-04-20          164         41                              16
# 2    06-04-20          123         35                              11
# 3    05-04-20           88         18                               6
# 4    04-04-20           70          9                               3
#
#   Case Growth Cases Growth 7DMA  Total Deaths  New Deaths  New Deaths 7DMA  \
# 0      32.93%            22.73%            20           3                2
# 1      33.33%            18.87%            17           5                2
# 2      39.77%            14.69%            12           3                1
# 3      25.71%             9.30%             9           1                1
# 4      14.75%             5.63%             8           2                0
#
#   Death Growth Death Growth 7DMA  Total Recoveries  New Recoveries  \
# ...

# %%
cases.isnull().sum()
# Out:
#        Date                       0
# Total Cases                       0
# New Cases                         0
# New Cases 7-Day Moving Average    0
# Case Growth                       0
# Cases Growth 7DMA                 0
# Total Deaths                      0
# New Deaths                        0
# New Deaths 7DMA                   0
# Death Growth                      0
# Death Growth 7DMA                 0
# Total Recoveries                  0
# New Recoveries                    0
# Recovery Rate                     0
# Active Cases                      0
# Case Fatality Rate (CFR)          0
# Adjusted CFR                      0
# Total Deaths per MM Population    0
# Total Cases per MM Population     0
# dtype: int64

# %%
# outlier or relationship analysis

correlation = cases.corr()

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(cases)

# %%
sns.relplot(x='Case Growth',y='New Cases',hue='New Cases 7-Day Moving Average',data=cases)

# %%
sns.distplot(cases['New Cases'],bins = 12)
# Out:
# C:\Users\SRTINNI\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='New Cases', ylabel='Density'>

# %%
bins= 12
plt.hist(cases['New Cases'],bins)
# Out:
# (array([22.,  5.,  1.,  0.,  1.,  0.,  0.,  1.,  0.,  1.,  0.,  1.]),
#  array([ 0. ,  4.5,  9. , 13.5, 18. , 22.5, 27. , 31.5, 36. , 40.5, 45. ,
#         49.5, 54. ]),
#  <BarContainer object of 12 artists>)
